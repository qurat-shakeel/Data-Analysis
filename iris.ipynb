# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
Iris = pd.read_csv("Iris.csv")
Iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
# print datapoints and features
print(Iris.shape)
# Out:
# (150, 6)

# %%
# column name in dataset
print(Iris.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
# data points for each class which are present
# number of flowers for which each species are present
Iris["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
# scatter plot
Iris.plot(kind='scatter' , x='SepalLengthCm' , y='SepalWidthCm')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-cc5fb7303b32> in <cell line: 3>()
#       1 # 2-D scatter plot with color-coding for each flower type/class
#       2 sns.set_style("whitegrid")
# ----> 3 sns.FacetGrid(data=Iris , hue="Species" , size=4)
#       4 map(plt.scatter,"SepalLengthCm","SepalWidthCm")
#       5 add.legend()
#
# TypeError: FacetGrid.__init__() got an unexpected keyword argument 'size'
